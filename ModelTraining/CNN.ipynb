# %% [markdown]
# # CNN

# %%
import pickle
from pprint import pprint

import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, ShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras import layers
from keras.backend import clear_session

# %% [markdown]
# #### Import data

# %%
# Dataframe
path_df = "../Pickles/df.pickle"
with open(path_df, 'rb') as data:
    df = pickle.load(data)

# features_train
path_features_train = "../Pickles/features_train.pickle"
with open(path_features_train, 'rb') as data:
    features_train = pickle.load(data)

# labels_train
path_labels_train = "../Pickles/labels_train.pickle"
with open(path_labels_train, 'rb') as data:
    labels_train = pickle.load(data)

# features_test
path_features_test = "../Pickles/features_test.pickle"
with open(path_features_test, 'rb') as data:
    features_test = pickle.load(data)

# labels_test
path_labels_test = "../Pickles/labels_test.pickle"
with open(path_labels_test, 'rb') as data:
    labels_test = pickle.load(data)

# %% [markdown]
# ### Remove strings from labels

# %%
labels_train.replace(to_replace='topic',value=2,inplace=True)
labels_test.replace(to_replace='topic',value=2,inplace=True)

# %% [markdown]
# ### Split data

# %%
features_train, features_validation, labels_train, labels_validation = train_test_split(features_train, 
                                                    labels_train, 
                                                    test_size=0.20, 
                                                    random_state=8)

# %% [markdown]
# ### Model train

# %%
input_dim = features_train.shape[1]  

model = Sequential()
model.add(layers.Dense(16, input_dim=input_dim, activation='relu'))
model.add(layers.Dense(8, activation='sigmoid'))
model.compile(loss='sparse_categorical_crossentropy', 
               optimizer='adam', 
               metrics=['accuracy'])
clear_session()
history = model.fit(features_train, labels_train,
                     epochs=100,
                     verbose=True,
                     validation_data=(features_validation, labels_validation),
                     batch_size=10)
# Out:
# Epoch 1/100
# 1186/1186 [==============================] - 2s 1ms/step - loss: 1.1165 - accuracy: 0.7182 - val_loss: 0.5947 - val_accuracy: 0.8265
# Epoch 2/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.4831 - accuracy: 0.8490 - val_loss: 0.4746 - val_accuracy: 0.8350
# Epoch 3/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.3868 - accuracy: 0.8713 - val_loss: 0.4477 - val_accuracy: 0.8394
# Epoch 4/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.3373 - accuracy: 0.8841 - val_loss: 0.4372 - val_accuracy: 0.8441
# Epoch 5/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.3032 - accuracy: 0.8939 - val_loss: 0.4417 - val_accuracy: 0.8441
# Epoch 6/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.2771 - accuracy: 0.9044 - val_loss: 0.4450 - val_accuracy: 0.8394
# Epoch 7/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.2562 - accuracy: 0.9126 - val_loss: 0.4519 - val_accuracy: 0.8353
# Epoch 8/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.2381 - accuracy: 0.9198 - val_loss: 0.4630 - val_accuracy: 0.8336
# Epoch 9/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.2221 - accuracy: 0.9266 - val_loss: 0.4727 - val_accuracy: 0.8326
# Epoch 10/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.2090 - accuracy: 0.9322 - val_loss: 0.4831 - val_accuracy: 0.8326
# Epoch 11/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1961 - accuracy: 0.9357 - val_loss: 0.5003 - val_accuracy: 0.8292
# Epoch 12/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1851 - accuracy: 0.9432 - val_loss: 0.5122 - val_accuracy: 0.8282
# Epoch 13/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1750 - accuracy: 0.9446 - val_loss: 0.5261 - val_accuracy: 0.8269
# Epoch 14/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1646 - accuracy: 0.9499 - val_loss: 0.5465 - val_accuracy: 0.8211
# Epoch 15/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1556 - accuracy: 0.9534 - val_loss: 0.5603 - val_accuracy: 0.8208
# Epoch 16/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1477 - accuracy: 0.9563 - val_loss: 0.5795 - val_accuracy: 0.8171
# Epoch 17/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1396 - accuracy: 0.9593 - val_loss: 0.5957 - val_accuracy: 0.8184
# Epoch 18/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1318 - accuracy: 0.9616 - val_loss: 0.6132 - val_accuracy: 0.8164
# Epoch 19/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1242 - accuracy: 0.9644 - val_loss: 0.6297 - val_accuracy: 0.8140
# Epoch 20/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1176 - accuracy: 0.9665 - val_loss: 0.6519 - val_accuracy: 0.8137
# Epoch 21/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1110 - accuracy: 0.9699 - val_loss: 0.6700 - val_accuracy: 0.8130
# Epoch 22/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.1045 - accuracy: 0.9715 - val_loss: 0.6915 - val_accuracy: 0.8110
# Epoch 23/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0981 - accuracy: 0.9738 - val_loss: 0.7080 - val_accuracy: 0.8103
# Epoch 24/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0927 - accuracy: 0.9754 - val_loss: 0.7263 - val_accuracy: 0.8090
# Epoch 25/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0869 - accuracy: 0.9776 - val_loss: 0.7466 - val_accuracy: 0.8107
# Epoch 26/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0817 - accuracy: 0.9800 - val_loss: 0.7686 - val_accuracy: 0.8107
# Epoch 27/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0767 - accuracy: 0.9821 - val_loss: 0.7916 - val_accuracy: 0.8110
# Epoch 28/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0715 - accuracy: 0.9833 - val_loss: 0.8102 - val_accuracy: 0.8080
# Epoch 29/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0672 - accuracy: 0.9848 - val_loss: 0.8348 - val_accuracy: 0.8097
# Epoch 30/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0629 - accuracy: 0.9857 - val_loss: 0.8598 - val_accuracy: 0.8070
# Epoch 31/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0588 - accuracy: 0.9873 - val_loss: 0.8835 - val_accuracy: 0.8073
# Epoch 32/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0538 - accuracy: 0.9897 - val_loss: 0.9067 - val_accuracy: 0.8066
# Epoch 33/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0506 - accuracy: 0.9892 - val_loss: 0.9302 - val_accuracy: 0.8066
# Epoch 34/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0472 - accuracy: 0.9904 - val_loss: 0.9535 - val_accuracy: 0.8093
# Epoch 35/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0437 - accuracy: 0.9916 - val_loss: 0.9807 - val_accuracy: 0.8066
# Epoch 36/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0404 - accuracy: 0.9929 - val_loss: 1.0053 - val_accuracy: 0.8036
# Epoch 37/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0373 - accuracy: 0.9936 - val_loss: 1.0328 - val_accuracy: 0.8056
# Epoch 38/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0340 - accuracy: 0.9943 - val_loss: 1.0571 - val_accuracy: 0.8039
# Epoch 39/100
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.0315 - accuracy: 0.9947 - val_loss: 1.0900 - val_accuracy: 0.8002
# Epoch 40/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0293 - accuracy: 0.9955 - val_loss: 1.1099 - val_accuracy: 0.7982
# Epoch 41/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0261 - accuracy: 0.9968 - val_loss: 1.1368 - val_accuracy: 0.8012
# Epoch 42/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0244 - accuracy: 0.9965 - val_loss: 1.1662 - val_accuracy: 0.8002
# Epoch 43/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0220 - accuracy: 0.9972 - val_loss: 1.1897 - val_accuracy: 0.7992
# Epoch 44/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0198 - accuracy: 0.9982 - val_loss: 1.2172 - val_accuracy: 0.8012
# Epoch 45/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0183 - accuracy: 0.9977 - val_loss: 1.2455 - val_accuracy: 0.7978
# Epoch 46/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0166 - accuracy: 0.9981 - val_loss: 1.2667 - val_accuracy: 0.8002
# Epoch 47/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0148 - accuracy: 0.9982 - val_loss: 1.3022 - val_accuracy: 0.8002
# Epoch 48/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0135 - accuracy: 0.9987 - val_loss: 1.3290 - val_accuracy: 0.7999
# Epoch 49/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0125 - accuracy: 0.9986 - val_loss: 1.3578 - val_accuracy: 0.7989
# Epoch 50/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0111 - accuracy: 0.9988 - val_loss: 1.3882 - val_accuracy: 0.7975
# Epoch 51/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0100 - accuracy: 0.9988 - val_loss: 1.4227 - val_accuracy: 0.7982
# Epoch 52/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0092 - accuracy: 0.9991 - val_loss: 1.4465 - val_accuracy: 0.7982
# Epoch 53/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0082 - accuracy: 0.9991 - val_loss: 1.4763 - val_accuracy: 0.7999
# Epoch 54/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0078 - accuracy: 0.9991 - val_loss: 1.5052 - val_accuracy: 0.7989
# Epoch 55/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0073 - accuracy: 0.9992 - val_loss: 1.5403 - val_accuracy: 0.7968
# Epoch 56/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0062 - accuracy: 0.9991 - val_loss: 1.5554 - val_accuracy: 0.7999
# Epoch 57/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0059 - accuracy: 0.9992 - val_loss: 1.5852 - val_accuracy: 0.7972
# Epoch 58/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0055 - accuracy: 0.9991 - val_loss: 1.6237 - val_accuracy: 0.7985
# Epoch 59/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0049 - accuracy: 0.9994 - val_loss: 1.6604 - val_accuracy: 0.7978
# Epoch 60/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0047 - accuracy: 0.9992 - val_loss: 1.6786 - val_accuracy: 0.7985
# Epoch 61/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 1.7158 - val_accuracy: 0.7931
# Epoch 62/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 1.7306 - val_accuracy: 0.7982
# Epoch 63/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0038 - accuracy: 0.9993 - val_loss: 1.7584 - val_accuracy: 0.7941
# Epoch 64/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 1.7903 - val_accuracy: 0.7982
# Epoch 65/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 1.8217 - val_accuracy: 0.7989
# Epoch 66/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 1.8511 - val_accuracy: 0.7958
# Epoch 67/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 1.8727 - val_accuracy: 0.7978
# Epoch 68/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 1.9085 - val_accuracy: 0.7948
# Epoch 69/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 1.9428 - val_accuracy: 0.7975
# Epoch 70/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 1.9703 - val_accuracy: 0.7958
# Epoch 71/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 1.9981 - val_accuracy: 0.7958
# Epoch 72/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 2.0183 - val_accuracy: 0.7965
# Epoch 73/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 2.0602 - val_accuracy: 0.7975
# Epoch 74/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 2.0779 - val_accuracy: 0.7962
# Epoch 75/100
# 1186/1186 [==============================] - 1s 974us/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 2.1164 - val_accuracy: 0.7945
# Epoch 76/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 2.1423 - val_accuracy: 0.7931
# Epoch 77/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 2.1714 - val_accuracy: 0.7951
# Epoch 78/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 2.2007 - val_accuracy: 0.7948
# Epoch 79/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 2.2265 - val_accuracy: 0.7948
# Epoch 80/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 2.2531 - val_accuracy: 0.7955
# Epoch 81/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 2.2883 - val_accuracy: 0.7945
# Epoch 82/100
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 2.3228 - val_accuracy: 0.7948
# Epoch 83/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 2.3508 - val_accuracy: 0.7941
# Epoch 84/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 2.3598 - val_accuracy: 0.7968
# Epoch 85/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 2.3874 - val_accuracy: 0.7951
# Epoch 86/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 2.4214 - val_accuracy: 0.7958
# Epoch 87/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 2.4579 - val_accuracy: 0.7935
# Epoch 88/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 2.4877 - val_accuracy: 0.7928
# Epoch 89/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 2.5159 - val_accuracy: 0.7938
# Epoch 90/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 2.5468 - val_accuracy: 0.7928
# Epoch 91/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 2.5654 - val_accuracy: 0.7951
# Epoch 92/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 2.5961 - val_accuracy: 0.7935
# Epoch 93/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 2.6283 - val_accuracy: 0.7924
# Epoch 94/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 2.6571 - val_accuracy: 0.7911
# Epoch 95/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 2.6880 - val_accuracy: 0.7914
# Epoch 96/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 2.7198 - val_accuracy: 0.7938
# Epoch 97/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 2.7507 - val_accuracy: 0.7921
# Epoch 98/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 2.7890 - val_accuracy: 0.7918
# Epoch 99/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 2.8174 - val_accuracy: 0.7948
# Epoch 100/100
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 2.8387 - val_accuracy: 0.7931

# %% [markdown]
# ### Results

# %%
loss, accuracy = model.evaluate(features_test, labels_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Testing Accuracy:  0.7904
